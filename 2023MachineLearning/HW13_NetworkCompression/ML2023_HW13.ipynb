# %% [markdown]
# # **Homework 12 - Reinforcement Learning**
#
# If you have any problem, e-mail us at mlta-2023-spring@googlegroups.com

# %% [markdown]
# ## Preliminary work
#
# First, we need to install all necessary packages.
# One of them, gym, builded by OpenAI, is a toolkit for developing Reinforcement Learning algorithm. Other packages are for visualization in colab.

# %%
# !apt update
# !apt install python-opengl xvfb -y
# !pip install -q swig
# !pip install box2d==2.3.2 gym[box2d]==0.25.2 box2d-py pyvirtualdisplay tqdm numpy==1.22.4
# !pip install box2d==2.3.2 box2d-kengz
# !pip freeze > requirements.txt
# Out:
# Hit:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:5 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:7 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:8 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:9 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:11 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:12 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [2,352 kB]
# Get:13 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,781 kB]
# Get:14 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1,060 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,359 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,282 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [2,539 kB]
# Fetched 13.7 MB in 2s (6,635 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 21 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   freeglut3 libfontenc1 libpython2-stdlib libxfont2 libxkbfile1 python2
#   python2-minimal x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common
# Suggested packages:
#   python-tk python-numpy libgle3 python2-doc
# The following NEW packages will be installed:
#   freeglut3 libfontenc1 libpython2-stdlib libxfont2 libxkbfile1 python-opengl
#   python2 python2-minimal x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common xvfb
# 0 upgraded, 14 newly installed, 0 to remove and 21 not upgraded.
# Need to get 8,318 kB of archives.
# After this operation, 18.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2-minimal amd64 2.7.17-2ubuntu4 [27.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libpython2-stdlib amd64 2.7.17-2ubuntu4 [7,072 B]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2 amd64 2.7.17-2ubuntu4 [26.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontenc1 amd64 1:1.1.4-0ubuntu1 [14.0 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfont2 amd64 1:2.0.3-1 [91.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbfile1 amd64 1:1.1.0-1 [65.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-opengl all 3.1.0+dfsg-2build1 [486 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 x11-xkb-utils amd64 7.7+5 [158 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu1 [573 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-utils amd64 1:7.7+6 [91.5 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 xserver-common all 2:1.20.13-1ubuntu1~20.04.8 [27.2 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 xvfb amd64 2:1.20.13-1ubuntu1~20.04.8 [780 kB]
# Fetched 8,318 kB in 0s (20.5 MB/s)
# Selecting previously unselected package python2-minimal.
# (Reading database ... 123069 files and directories currently installed.)
# Preparing to unpack .../python2-minimal_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package libpython2-stdlib:amd64.
# Preparing to unpack .../libpython2-stdlib_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package python2.
# (Reading database ... 123098 files and directories currently installed.)
# Preparing to unpack .../00-python2_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2 (2.7.17-2ubuntu4) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../01-freeglut3_2.8.1-3_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-3) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../02-libfontenc1_1%3a1.1.4-0ubuntu1_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../03-libxfont2_1%3a2.0.3-1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.3-1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../04-libxkbfile1_1%3a1.1.0-1_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1) ...
# Selecting previously unselected package python-opengl.
# Preparing to unpack .../05-python-opengl_3.1.0+dfsg-2build1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-2build1) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../06-x11-xkb-utils_7.7+5_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../07-xfonts-encodings_1%3a1.0.5-0ubuntu1_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu1) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../08-xfonts-utils_1%3a7.7+6_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../09-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../10-xserver-common_2%3a1.20.13-1ubuntu1~20.04.8_all.deb ...
# Unpacking xserver-common (2:1.20.13-1ubuntu1~20.04.8) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../11-xvfb_2%3a1.20.13-1ubuntu1~20.04.8_amd64.deb ...
# Unpacking xvfb (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2 (2.7.17-2ubuntu4) ...
# Setting up libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1) ...
# Setting up libxfont2:amd64 (1:2.0.3-1) ...
# Setting up python-opengl (3.1.0+dfsg-2build1) ...
# Setting up x11-xkb-utils (7.7+5) ...
# Setting up xfonts-utils (1:7.7+6) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up xvfb (2:1.20.13-1ubuntu1~20.04.8) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.8 MB/s eta 0:00:00
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting box2d==2.3.2
#   Downloading Box2D-2.3.2.tar.gz (427 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.9/427.9 kB 15.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gym[box2d]==0.25.2 in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Collecting box2d-py
#   Downloading box2d-py-2.3.8.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.5/374.5 kB 32.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)
# Requirement already satisfied: numpy==1.22.4 in /usr/local/lib/python3.10/dist-packages (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]==0.25.2) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]==0.25.2) (0.0.8)
# Collecting box2d-py
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 26.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pygame==2.1.0 (from gym[box2d]==0.25.2)
#   Downloading pygame-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 55.9 MB/s eta 0:00:00
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from gym[box2d]==0.25.2) (4.1.1)
# Building wheels for collected packages: box2d, box2d-py
#   Building wheel for box2d (setup.py) ... done
#   Created wheel for box2d: filename=Box2D-2.3.2-cp310-cp310-linux_x86_64.whl size=2830379 sha256=ee60a0d938a12f12f88f1234fdbe0df2ea15914255b708d64dc5624b3f3ce722
#   Stored in directory: /root/.cache/pip/wheels/eb/cb/be/e663f3ce9aba6580611c0febaf7cd3cf7603f87047de2a52f9
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2812325 sha256=aa30f19c68d173ef159debc434038701fa31b7010bc7a6785c55cfcc63a2a231
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d box2d-py
# Installing collected packages: pyvirtualdisplay, box2d-py, box2d, pygame
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.3.0
#     Uninstalling pygame-2.3.0:
#       Successfully uninstalled pygame-2.3.0
# Successfully installed box2d-2.3.2 box2d-py-2.3.5 pygame-2.1.0 pyvirtualdisplay-3.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: box2d==2.3.2 in /usr/local/lib/python3.10/dist-packages (2.3.2)
# Collecting box2d-kengz
#   Downloading Box2D-kengz-2.3.3.tar.gz (425 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.4/425.4 kB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: box2d-kengz
#   Building wheel for box2d-kengz (setup.py) ... done
#   Created wheel for box2d-kengz: filename=Box2D_kengz-2.3.3-cp310-cp310-linux_x86_64.whl size=2830065 sha256=84483d23890970a31e601600a4184034c09086388fb5924d7c1daee75dfa01e4
#   Stored in directory: /root/.cache/pip/wheels/ab/a3/5f/6396406aa0163da86c2a8d28304a120b55cfa98363654d853b
# Successfully built box2d-kengz
# Installing collected packages: box2d-kengz
# Successfully installed box2d-kengz-2.3.3

# %% [markdown]
# Next, set up virtual display，and import all necessaary packages.

# %%
# %%capture
from pyvirtualdisplay import Display
virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %matplotlib inline
import matplotlib.pyplot as plt

from IPython import display

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical
from tqdm.notebook import tqdm

# %% [markdown]
# # Warning ! Do not revise random seed !!!
# # Your submission on JudgeBoi will not reproduce your result !!!
# Make your HW result to be reproducible.

# %%
seed = 2023 # Do not change this
def fix(env, seed):
  env.seed(seed)
  env.action_space.seed(seed)
  torch.backends.cudnn.deterministic = True
  torch.backends.cudnn.benchmark = False
  np.random.seed(seed)
  torch.manual_seed(seed)
  if torch.cuda.is_available():
      torch.cuda.manual_seed_all(seed)

# %% [markdown]
# Last, call gym and build an [Lunar Lander](https://gym.openai.com/envs/LunarLander-v2/) environment.

# %%
# %%capture
import gym
import random
env = gym.make('LunarLander-v2')
fix(env, seed) # fix the environment Do not revise this !!!

# %% [markdown]
# ## What Lunar Lander？
#
# “LunarLander-v2”is to simulate the situation when the craft lands on the surface of the moon.
#
# This task is to enable the craft to land "safely" at the pad between the two yellow flags.
# > Landing pad is always at coordinates (0,0).
# > Coordinates are the first two numbers in state vector.
#
# ![](https://gym.openai.com/assets/docs/aeloop-138c89d44114492fd02822303e6b4b07213010bb14ca5856d2d49d6b62d88e53.svg)
#
# "LunarLander-v2" actually includes "Agent" and "Environment".
#
# In this homework, we will utilize the function `step()` to control the action of "Agent".
#
# Then `step()` will return the observation/state and reward given by the "Environment".

# %% [markdown]
# ### Observation / State
#
# First, we can take a look at what an Observation / State looks like.

# %%
print(env.observation_space)
# Out:
# Box([-1.5       -1.5       -5.        -5.        -3.1415927 -5.
#  -0.        -0.       ], [1.5       1.5       5.        5.        3.1415927 5.        1.
#  1.       ], (8,), float32)

# %% [markdown]
# `Box(8,)`means that observation is an 8-dim vector
# ### Action
#
# Actions can be taken by looks like

# %%
print(env.action_space)
# Out:
# Discrete(4)

# %% [markdown]
# `Discrete(4)` implies that there are four kinds of actions can be taken by agent.
# - 0 implies the agent will not take any actions
# - 2 implies the agent will accelerate downward
# - 1, 3 implies the agent will accelerate left and right
#
# Next, we will try to make the agent interact with the environment.
# Before taking any actions, we recommend to call `reset()` function to reset the environment. Also, this function will return the initial state of the environment.

# %%
initial_state = env.reset()
print(initial_state)
# Out:
# [-0.00506535  1.413064   -0.5130838   0.09527162  0.00587628  0.11622101
#   0.          0.        ]

# %% [markdown]
# Then, we try to get a random action from the agent's action space.

# %%
random_action = env.action_space.sample()
print(random_action)
# Out:
# 1

# %% [markdown]
# More, we can utilize `step()` to make agent act according to the randomly-selected `random_action`.
# The `step()` function will return four values:
# - observation / state
# - reward
# - done (True/ False)
# - Other information

# %%
observation, reward, done, info = env.step(random_action)

# %%
print(done)
# Out:
# False

# %% [markdown]
# ### Reward
#
#
# > Landing pad is always at coordinates (0,0). Coordinates are the first two numbers in state vector. Reward for moving from the top of the screen to landing pad and zero speed is about 100..140 points. If lander moves away from landing pad it loses reward back. Episode finishes if the lander crashes or comes to rest, receiving additional -100 or +100 points. Each leg ground contact is +10. Firing main engine is -0.3 points each frame. Solved is 200 points.

# %%
print(reward)
# Out:
# -1.4981841929643156

# %% [markdown]
# ### Random Agent
# In the end, before we start training, we can see whether a random agent can successfully land the moon or not.

# %%
env.reset()

img = plt.imshow(env.render(mode='rgb_array'))

done = False
while not done:
    action = env.action_space.sample()
    observation, reward, done, _ = env.step(action)

    img.set_data(env.render(mode='rgb_array'))
    display.display(plt.gcf())
    display.clear_output(wait=True)

# %% [markdown]
# ## Policy Gradient
# Now, we can build a simple policy network. The network will return one of action in the action space.

# %%
class PolicyGradientNetwork(nn.Module):


    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(8, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 4)

    def forward(self, state):
        hid = torch.tanh(self.fc1(state))
        hid = torch.tanh(hid)
        return F.softmax(self.fc3(hid), dim=-1)

# %% [markdown]
# Then, we need to build a simple agent. The agent will acts according to the output of the policy network above. There are a few things can be done by agent:
# - `learn()`：update the policy network from log probabilities and rewards.
# - `sample()`：After receiving observation from the environment, utilize policy network to tell which action to take. The return values of this function includes action and log probabilities.

# %%
from torch.optim.lr_scheduler import StepLR
class PolicyGradientAgent():

    def __init__(self, network):
        self.network = network
        self.optimizer = optim.AdamW(self.network.parameters(), lr=0.001,weight_decay=0.1)

    def forward(self, state):
        return self.network(state)
    def learn(self, log_probs, rewards):
        loss = (-log_probs * rewards).sum() # You don't need to revise this to pass simple baseline (but you can)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def sample(self, state):
        action_prob = self.network(torch.FloatTensor(state))
        action_dist = Categorical(action_prob)
        action = action_dist.sample()
        log_prob = action_dist.log_prob(action)
        return action.item(), log_prob

# %% [markdown]
# Lastly, build a network and agent to start training.

# %%
network = PolicyGradientNetwork()
agent = PolicyGradientAgent(network)

# %% [markdown]
# ## Training Agent
#
# Now let's start to train our agent.
# Through taking all the interactions between agent and environment as training data, the policy network can learn from all these attempts,

# %%
agent.network.train()  # Switch network into training mode
EPISODE_PER_BATCH = 20  # update the  agent every 5 episode
NUM_BATCH = 1000      # totally update the agent for 500 time

avg_total_rewards, avg_final_rewards = [], []

prg_bar = tqdm(range(NUM_BATCH))
for batch in prg_bar:

    log_probs, rewards = [], []
    total_rewards, final_rewards = [], []

    # collect trajectory
    for episode in range(EPISODE_PER_BATCH):

        state = env.reset()
        total_reward, total_step = 0, 0
        seq_rewards = []
        while True:

            action, log_prob = agent.sample(state) # at, log(at|st)
            next_state, reward, done, _ = env.step(action)

            log_probs.append(log_prob) # [log(a1|s1), log(a2|s2), ...., log(at|st)]
            seq_rewards.append(reward)
            state = next_state
            total_reward += reward
            total_step += 1
            #rewards.append(reward) # change here
            # ! IMPORTANT !
            # Current reward implementation: immediate reward,  given action_list : a1, a2, a3 ......
            #                                                         rewards :     r1, r2 ,r3 ......
            # medium：change "rewards" to accumulative decaying reward, given action_list : a1,                           a2,                           a3, ......
            #                                                           rewards :           r1+0.99*r2+0.99^2*r3+......, r2+0.99*r3+0.99^2*r4+...... ,  r3+0.99*r4+0.99^2*r5+ ......
            # boss : implement Actor-Critic
            if done:


                for i in range(1,total_step):
                  seq_rewards[total_step-1-i]+= seq_rewards[total_step-i]*0.97
                rewards.extend(seq_rewards)

                final_rewards.append(reward)
                total_rewards.append(total_reward)

                break

    print(f"rewards looks like ", np.shape(rewards))
    #print(f"log_probs looks like ", np.shape(log_probs))
    # record training process
    avg_total_reward = sum(total_rewards) / len(total_rewards)
    avg_final_reward = sum(final_rewards) / len(final_rewards)
    avg_total_rewards.append(avg_total_reward)
    avg_final_rewards.append(avg_final_reward)
    prg_bar.set_description(f"Total: {avg_total_reward: 4.1f}, Final: {avg_final_reward: 4.1f}")

    # update agent
    # rewards = np.concatenate(rewards, axis=0)
    rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-9)  # normalize the reward
    agent.learn(torch.stack(log_probs), torch.from_numpy(rewards))
    print("logs prob looks like ", torch.stack(log_probs).size())
    print("torch.from_numpy(rewards) looks like ", torch.from_numpy(rewards).size())
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# rewards looks like  (1620,)
# logs prob looks like  torch.Size([1620])
# torch.from_numpy(rewards) looks like  torch.Size([1620])
# rewards looks like  (1771,)
# logs prob looks like  torch.Size([1771])
# torch.from_numpy(rewards) looks like  torch.Size([1771])
# rewards looks like  (1743,)
# logs prob looks like  torch.Size([1743])
# torch.from_numpy(rewards) looks like  torch.Size([1743])
# rewards looks like  (1755,)
# logs prob looks like  torch.Size([1755])
# torch.from_numpy(rewards) looks like  torch.Size([1755])
# rewards looks like  (1763,)
# logs prob looks like  torch.Size([1763])
# torch.from_numpy(rewards) looks like  torch.Size([1763])
# rewards looks like  (1708,)
# logs prob looks like  torch.Size([1708])
# torch.from_numpy(rewards) looks like  torch.Size([1708])
# rewards looks like  (1706,)
# logs prob looks like  torch.Size([1706])
# torch.from_numpy(rewards) looks like  torch.Size([1706])
# rewards looks like  (1873,)
# logs prob looks like  torch.Size([1873])
# torch.from_numpy(rewards) looks like  torch.Size([1873])
# rewards looks like  (1739,)
# logs prob looks like  torch.Size([1739])
# torch.from_numpy(rewards) looks like  torch.Size([1739])
# rewards looks like  (1807,)
# logs prob looks like  torch.Size([1807])
# torch.from_numpy(rewards) looks like  torch.Size([1807])
# rewards looks like  (1817,)
# logs prob looks like  torch.Size([1817])
# torch.from_numpy(rewards) looks like  torch.Size([1817])
# rewards looks like  (1713,)
# logs prob looks like  torch.Size([1713])
# torch.from_numpy(rewards) looks like  torch.Size([1713])
# rewards looks like  (1868,)
# logs prob looks like  torch.Size([1868])
# torch.from_numpy(rewards) looks like  torch.Size([1868])
# rewards looks like  (1762,)
# logs prob looks like  torch.Size([1762])
# torch.from_numpy(rewards) looks like  torch.Size([1762])
# rewards looks like  (1720,)
# logs prob looks like  torch.Size([1720])
# torch.from_numpy(rewards) looks like  torch.Size([1720])
# rewards looks like  (1785,)
# logs prob looks like  torch.Size([1785])
# torch.from_numpy(rewards) looks like  torch.Size([1785])
# rewards looks like  (1835,)
# logs prob looks like  torch.Size([1835])
# torch.from_numpy(rewards) looks like  torch.Size([1835])
# rewards looks like  (1834,)
# logs prob looks like  torch.Size([1834])
# torch.from_numpy(rewards) looks like  torch.Size([1834])
# rewards looks like  (1929,)
# logs prob looks like  torch.Size([1929])
# torch.from_numpy(rewards) looks like  torch.Size([1929])
# rewards looks like  (1874,)
# logs prob looks like  torch.Size([1874])
# torch.from_numpy(rewards) looks like  torch.Size([1874])
# rewards looks like  (1989,)
# logs prob looks like  torch.Size([1989])
# torch.from_numpy(rewards) looks like  torch.Size([1989])
# rewards looks like  (1819,)
# logs prob looks like  torch.Size([1819])
# torch.from_numpy(rewards) looks like  torch.Size([1819])
# rewards looks like  (1884,)
# logs prob looks like  torch.Size([1884])
# torch.from_numpy(rewards) looks like  torch.Size([1884])
# rewards looks like  (1818,)
# logs prob looks like  torch.Size([1818])
# torch.from_numpy(rewards) looks like  torch.Size([1818])
# rewards looks like  (1940,)
# logs prob looks like  torch.Size([1940])
# torch.from_numpy(rewards) looks like  torch.Size([1940])
# rewards looks like  (2033,)
# logs prob looks like  torch.Size([2033])
# torch.from_numpy(rewards) looks like  torch.Size([2033])
# rewards looks like  (1846,)
# logs prob looks like  torch.Size([1846])
# torch.from_numpy(rewards) looks like  torch.Size([1846])
# rewards looks like  (1780,)
# logs prob looks like  torch.Size([1780])
# torch.from_numpy(rewards) looks like  torch.Size([1780])
# rewards looks like  (1737,)
# logs prob looks like  torch.Size([1737])
# torch.from_numpy(rewards) looks like  torch.Size([1737])
# rewards looks like  (1857,)
# logs prob looks like  torch.Size([1857])
# torch.from_numpy(rewards) looks like  torch.Size([1857])
# rewards looks like  (1743,)
# logs prob looks like  torch.Size([1743])
# torch.from_numpy(rewards) looks like  torch.Size([1743])
# rewards looks like  (1910,)
# logs prob looks like  torch.Size([1910])
# torch.from_numpy(rewards) looks like  torch.Size([1910])
# rewards looks like  (1747,)
# logs prob looks like  torch.Size([1747])
# torch.from_numpy(rewards) looks like  torch.Size([1747])
# rewards looks like  (1906,)
# logs prob looks like  torch.Size([1906])
# torch.from_numpy(rewards) looks like  torch.Size([1906])
# rewards looks like  (1833,)
# logs prob looks like  torch.Size([1833])
# torch.from_numpy(rewards) looks like  torch.Size([1833])
# rewards looks like  (1914,)
# logs prob looks like  torch.Size([1914])
# torch.from_numpy(rewards) looks like  torch.Size([1914])
# rewards looks like  (1956,)
# logs prob looks like  torch.Size([1956])
# torch.from_numpy(rewards) looks like  torch.Size([1956])
# rewards looks like  (1831,)
# logs prob looks like  torch.Size([1831])
# torch.from_numpy(rewards) looks like  torch.Size([1831])
# rewards looks like  (1820,)
# logs prob looks like  torch.Size([1820])
# torch.from_numpy(rewards) looks like  torch.Size([1820])
# rewards looks like  (1930,)
# logs prob looks like  torch.Size([1930])
# torch.from_numpy(rewards) looks like  torch.Size([1930])
# rewards looks like  (1847,)
# logs prob looks like  torch.Size([1847])
# torch.from_numpy(rewards) looks like  torch.Size([1847])
# rewards looks like  (1940,)
# logs prob looks like  torch.Size([1940])
# torch.from_numpy(rewards) looks like  torch.Size([1940])
# rewards looks like  (1858,)
# logs prob looks like  torch.Size([1858])
# torch.from_numpy(rewards) looks like  torch.Size([1858])
# rewards looks like  (1837,)
# logs prob looks like  torch.Size([1837])
# torch.from_numpy(rewards) looks like  torch.Size([1837])
# rewards looks like  (2037,)
# logs prob looks like  torch.Size([2037])
# torch.from_numpy(rewards) looks like  torch.Size([2037])
# rewards looks like  (1876,)
# logs prob looks like  torch.Size([1876])
# torch.from_numpy(rewards) looks like  torch.Size([1876])
# rewards looks like  (1992,)
# logs prob looks like  torch.Size([1992])
# torch.from_numpy(rewards) looks like  torch.Size([1992])
# rewards looks like  (1917,)
# logs prob looks like  torch.Size([1917])
# torch.from_numpy(rewards) looks like  torch.Size([1917])
# rewards looks like  (1891,)
# logs prob looks like  torch.Size([1891])
# torch.from_numpy(rewards) looks like  torch.Size([1891])
# rewards looks like  (2086,)
# logs prob looks like  torch.Size([2086])
# torch.from_numpy(rewards) looks like  torch.Size([2086])
# rewards looks like  (1902,)
# logs prob looks like  torch.Size([1902])
# torch.from_numpy(rewards) looks like  torch.Size([1902])
# rewards looks like  (1970,)
# logs prob looks like  torch.Size([1970])
# torch.from_numpy(rewards) looks like  torch.Size([1970])
# rewards looks like  (1913,)
# logs prob looks like  torch.Size([1913])
# torch.from_numpy(rewards) looks like  torch.Size([1913])
# rewards looks like  (2860,)
# logs prob looks like  torch.Size([2860])
# torch.from_numpy(rewards) looks like  torch.Size([2860])
# rewards looks like  (1994,)
# logs prob looks like  torch.Size([1994])
# torch.from_numpy(rewards) looks like  torch.Size([1994])
# rewards looks like  (1995,)
# logs prob looks like  torch.Size([1995])
# torch.from_numpy(rewards) looks like  torch.Size([1995])
# rewards looks like  (1963,)
# logs prob looks like  torch.Size([1963])
# torch.from_numpy(rewards) looks like  torch.Size([1963])
# rewards looks like  (2015,)
# logs prob looks like  torch.Size([2015])
# torch.from_numpy(rewards) looks like  torch.Size([2015])
# rewards looks like  (1792,)
# logs prob looks like  torch.Size([1792])
# torch.from_numpy(rewards) looks like  torch.Size([1792])
# rewards looks like  (2014,)
# logs prob looks like  torch.Size([2014])
# torch.from_numpy(rewards) looks like  torch.Size([2014])
# rewards looks like  (1947,)
# logs prob looks like  torch.Size([1947])
# torch.from_numpy(rewards) looks like  torch.Size([1947])
# rewards looks like  (2079,)
# logs prob looks like  torch.Size([2079])
# torch.from_numpy(rewards) looks like  torch.Size([2079])
# rewards looks like  (1888,)
# logs prob looks like  torch.Size([1888])
# torch.from_numpy(rewards) looks like  torch.Size([1888])
# rewards looks like  (1938,)
# logs prob looks like  torch.Size([1938])
# torch.from_numpy(rewards) looks like  torch.Size([1938])
# rewards looks like  (2211,)
# logs prob looks like  torch.Size([2211])
# torch.from_numpy(rewards) looks like  torch.Size([2211])
# rewards looks like  (2423,)
# logs prob looks like  torch.Size([2423])
# torch.from_numpy(rewards) looks like  torch.Size([2423])
# rewards looks like  (2289,)
# logs prob looks like  torch.Size([2289])
# torch.from_numpy(rewards) looks like  torch.Size([2289])
# rewards looks like  (2175,)
# logs prob looks like  torch.Size([2175])
# torch.from_numpy(rewards) looks like  torch.Size([2175])
# rewards looks like  (2192,)
# logs prob looks like  torch.Size([2192])
# torch.from_numpy(rewards) looks like  torch.Size([2192])
# rewards looks like  (2312,)
# logs prob looks like  torch.Size([2312])
# torch.from_numpy(rewards) looks like  torch.Size([2312])
# rewards looks like  (2247,)
# logs prob looks like  torch.Size([2247])
# torch.from_numpy(rewards) looks like  torch.Size([2247])
# rewards looks like  (2195,)
# logs prob looks like  torch.Size([2195])
# torch.from_numpy(rewards) looks like  torch.Size([2195])
# rewards looks like  (2216,)
# logs prob looks like  torch.Size([2216])
# torch.from_numpy(rewards) looks like  torch.Size([2216])
# rewards looks like  (2163,)
# logs prob looks like  torch.Size([2163])
# torch.from_numpy(rewards) looks like  torch.Size([2163])
# rewards looks like  (2033,)
# logs prob looks like  torch.Size([2033])
# torch.from_numpy(rewards) looks like  torch.Size([2033])
# rewards looks like  (2475,)
# logs prob looks like  torch.Size([2475])
# torch.from_numpy(rewards) looks like  torch.Size([2475])
# rewards looks like  (2231,)
# logs prob looks like  torch.Size([2231])
# torch.from_numpy(rewards) looks like  torch.Size([2231])
# rewards looks like  (2152,)
# logs prob looks like  torch.Size([2152])
# torch.from_numpy(rewards) looks like  torch.Size([2152])
# rewards looks like  (2268,)
# logs prob looks like  torch.Size([2268])
# torch.from_numpy(rewards) looks like  torch.Size([2268])
# rewards looks like  (2455,)
# logs prob looks like  torch.Size([2455])
# torch.from_numpy(rewards) looks like  torch.Size([2455])
# rewards looks like  (3431,)
# logs prob looks like  torch.Size([3431])
# torch.from_numpy(rewards) looks like  torch.Size([3431])
# rewards looks like  (3527,)
# logs prob looks like  torch.Size([3527])
# torch.from_numpy(rewards) looks like  torch.Size([3527])
# rewards looks like  (2508,)
# logs prob looks like  torch.Size([2508])
# torch.from_numpy(rewards) looks like  torch.Size([2508])
# rewards looks like  (2281,)
# logs prob looks like  torch.Size([2281])
# torch.from_numpy(rewards) looks like  torch.Size([2281])
# rewards looks like  (2148,)
# logs prob looks like  torch.Size([2148])
# torch.from_numpy(rewards) looks like  torch.Size([2148])
# rewards looks like  (2393,)
# logs prob looks like  torch.Size([2393])
# torch.from_numpy(rewards) looks like  torch.Size([2393])
# rewards looks like  (3364,)
# logs prob looks like  torch.Size([3364])
# torch.from_numpy(rewards) looks like  torch.Size([3364])
# rewards looks like  (3187,)
# logs prob looks like  torch.Size([3187])
# torch.from_numpy(rewards) looks like  torch.Size([3187])
# rewards looks like  (2263,)
# logs prob looks like  torch.Size([2263])
# torch.from_numpy(rewards) looks like  torch.Size([2263])
# rewards looks like  (2666,)
# logs prob looks like  torch.Size([2666])
# torch.from_numpy(rewards) looks like  torch.Size([2666])
# rewards looks like  (2442,)
# logs prob looks like  torch.Size([2442])
# torch.from_numpy(rewards) looks like  torch.Size([2442])
# rewards looks like  (2441,)
# logs prob looks like  torch.Size([2441])
# torch.from_numpy(rewards) looks like  torch.Size([2441])
# rewards looks like  (2370,)
# logs prob looks like  torch.Size([2370])
# torch.from_numpy(rewards) looks like  torch.Size([2370])
# rewards looks like  (2460,)
# logs prob looks like  torch.Size([2460])
# torch.from_numpy(rewards) looks like  torch.Size([2460])
# rewards looks like  (2721,)
# logs prob looks like  torch.Size([2721])
# torch.from_numpy(rewards) looks like  torch.Size([2721])
# rewards looks like  (2474,)
# logs prob looks like  torch.Size([2474])
# torch.from_numpy(rewards) looks like  torch.Size([2474])
# rewards looks like  (2655,)
# logs prob looks like  torch.Size([2655])
# torch.from_numpy(rewards) looks like  torch.Size([2655])
# rewards looks like  (3248,)
# logs prob looks like  torch.Size([3248])
# torch.from_numpy(rewards) looks like  torch.Size([3248])
# rewards looks like  (2358,)
# logs prob looks like  torch.Size([2358])
# torch.from_numpy(rewards) looks like  torch.Size([2358])
# rewards looks like  (2522,)
# logs prob looks like  torch.Size([2522])
# torch.from_numpy(rewards) looks like  torch.Size([2522])
# rewards looks like  (2809,)
# logs prob looks like  torch.Size([2809])
# torch.from_numpy(rewards) looks like  torch.Size([2809])
# rewards looks like  (2540,)
# logs prob looks like  torch.Size([2540])
# torch.from_numpy(rewards) looks like  torch.Size([2540])
# rewards looks like  (2450,)
# logs prob looks like  torch.Size([2450])
# torch.from_numpy(rewards) looks like  torch.Size([2450])
# rewards looks like  (2559,)
# logs prob looks like  torch.Size([2559])
# torch.from_numpy(rewards) looks like  torch.Size([2559])
# rewards looks like  (2680,)
# logs prob looks like  torch.Size([2680])
# torch.from_numpy(rewards) looks like  torch.Size([2680])
# rewards looks like  (2446,)
# logs prob looks like  torch.Size([2446])
# torch.from_numpy(rewards) looks like  torch.Size([2446])
# rewards looks like  (3275,)
# logs prob looks like  torch.Size([3275])
# torch.from_numpy(rewards) looks like  torch.Size([3275])
# rewards looks like  (2478,)
# logs prob looks like  torch.Size([2478])
# torch.from_numpy(rewards) looks like  torch.Size([2478])
# rewards looks like  (2603,)
# logs prob looks like  torch.Size([2603])
# torch.from_numpy(rewards) looks like  torch.Size([2603])
# rewards looks like  (2760,)
# logs prob looks like  torch.Size([2760])
# torch.from_numpy(rewards) looks like  torch.Size([2760])
# rewards looks like  (2450,)
# logs prob looks like  torch.Size([2450])
# torch.from_numpy(rewards) looks like  torch.Size([2450])
# rewards looks like  (2489,)
# logs prob looks like  torch.Size([2489])
# torch.from_numpy(rewards) looks like  torch.Size([2489])
# rewards looks like  (2660,)
# logs prob looks like  torch.Size([2660])
# torch.from_numpy(rewards) looks like  torch.Size([2660])
# rewards looks like  (2726,)
# logs prob looks like  torch.Size([2726])
# torch.from_numpy(rewards) looks like  torch.Size([2726])
# rewards looks like  (2628,)
# logs prob looks like  torch.Size([2628])
# torch.from_numpy(rewards) looks like  torch.Size([2628])
# rewards looks like  (2598,)
# logs prob looks like  torch.Size([2598])
# torch.from_numpy(rewards) looks like  torch.Size([2598])
# rewards looks like  (2594,)
# logs prob looks like  torch.Size([2594])
# torch.from_numpy(rewards) looks like  torch.Size([2594])
# rewards looks like  (2472,)
# logs prob looks like  torch.Size([2472])
# torch.from_numpy(rewards) looks like  torch.Size([2472])
# rewards looks like  (2657,)
# logs prob looks like  torch.Size([2657])
# torch.from_numpy(rewards) looks like  torch.Size([2657])
# rewards looks like  (2425,)
# logs prob looks like  torch.Size([2425])
# torch.from_numpy(rewards) looks like  torch.Size([2425])
# rewards looks like  (2940,)
# logs prob looks like  torch.Size([2940])
# torch.from_numpy(rewards) looks like  torch.Size([2940])
# rewards looks like  (2599,)
# logs prob looks like  torch.Size([2599])
# torch.from_numpy(rewards) looks like  torch.Size([2599])
# rewards looks like  (2763,)
# logs prob looks like  torch.Size([2763])
# torch.from_numpy(rewards) looks like  torch.Size([2763])
# rewards looks like  (2686,)
# logs prob looks like  torch.Size([2686])
# torch.from_numpy(rewards) looks like  torch.Size([2686])
# rewards looks like  (2612,)
# logs prob looks like  torch.Size([2612])
# torch.from_numpy(rewards) looks like  torch.Size([2612])
# rewards looks like  (2618,)
# logs prob looks like  torch.Size([2618])
# torch.from_numpy(rewards) looks like  torch.Size([2618])
# rewards looks like  (2488,)
# logs prob looks like  torch.Size([2488])
# torch.from_numpy(rewards) looks like  torch.Size([2488])
# rewards looks like  (3619,)
# logs prob looks like  torch.Size([3619])
# torch.from_numpy(rewards) looks like  torch.Size([3619])
# rewards looks like  (3463,)
# logs prob looks like  torch.Size([3463])
# torch.from_numpy(rewards) looks like  torch.Size([3463])
# rewards looks like  (2603,)
# logs prob looks like  torch.Size([2603])
# torch.from_numpy(rewards) looks like  torch.Size([2603])
# rewards looks like  (2788,)
# logs prob looks like  torch.Size([2788])
# torch.from_numpy(rewards) looks like  torch.Size([2788])
# rewards looks like  (2717,)
# logs prob looks like  torch.Size([2717])
# torch.from_numpy(rewards) looks like  torch.Size([2717])
# rewards looks like  (2823,)
# logs prob looks like  torch.Size([2823])
# torch.from_numpy(rewards) looks like  torch.Size([2823])
# rewards looks like  (3580,)
# logs prob looks like  torch.Size([3580])
# torch.from_numpy(rewards) looks like  torch.Size([3580])
# rewards looks like  (3443,)
# logs prob looks like  torch.Size([3443])
# torch.from_numpy(rewards) looks like  torch.Size([3443])
# rewards looks like  (2898,)
# logs prob looks like  torch.Size([2898])
# torch.from_numpy(rewards) looks like  torch.Size([2898])
# rewards looks like  (3459,)
# logs prob looks like  torch.Size([3459])
# torch.from_numpy(rewards) looks like  torch.Size([3459])
# rewards looks like  (2756,)
# logs prob looks like  torch.Size([2756])
# torch.from_numpy(rewards) looks like  torch.Size([2756])
# rewards looks like  (4110,)
# logs prob looks like  torch.Size([4110])
# torch.from_numpy(rewards) looks like  torch.Size([4110])
# rewards looks like  (3005,)
# logs prob looks like  torch.Size([3005])
# torch.from_numpy(rewards) looks like  torch.Size([3005])
# rewards looks like  (2953,)
# logs prob looks like  torch.Size([2953])
# torch.from_numpy(rewards) looks like  torch.Size([2953])
# rewards looks like  (2982,)
# logs prob looks like  torch.Size([2982])
# torch.from_numpy(rewards) looks like  torch.Size([2982])
# rewards looks like  (2965,)
# logs prob looks like  torch.Size([2965])
# torch.from_numpy(rewards) looks like  torch.Size([2965])
# rewards looks like  (2785,)
# logs prob looks like  torch.Size([2785])
# torch.from_numpy(rewards) looks like  torch.Size([2785])
# rewards looks like  (2829,)
# logs prob looks like  torch.Size([2829])
# torch.from_numpy(rewards) looks like  torch.Size([2829])
# rewards looks like  (3569,)
# logs prob looks like  torch.Size([3569])
# torch.from_numpy(rewards) looks like  torch.Size([3569])
# rewards looks like  (2955,)
# logs prob looks like  torch.Size([2955])
# torch.from_numpy(rewards) looks like  torch.Size([2955])
# rewards looks like  (3704,)
# logs prob looks like  torch.Size([3704])
# torch.from_numpy(rewards) looks like  torch.Size([3704])
# rewards looks like  (2781,)
# logs prob looks like  torch.Size([2781])
# torch.from_numpy(rewards) looks like  torch.Size([2781])
# rewards looks like  (2804,)
# logs prob looks like  torch.Size([2804])
# torch.from_numpy(rewards) looks like  torch.Size([2804])
# rewards looks like  (3746,)
# logs prob looks like  torch.Size([3746])
# torch.from_numpy(rewards) looks like  torch.Size([3746])
# rewards looks like  (2618,)
# logs prob looks like  torch.Size([2618])
# torch.from_numpy(rewards) looks like  torch.Size([2618])
# rewards looks like  (3730,)
# logs prob looks like  torch.Size([3730])
# torch.from_numpy(rewards) looks like  torch.Size([3730])
# rewards looks like  (2875,)
# logs prob looks like  torch.Size([2875])
# torch.from_numpy(rewards) looks like  torch.Size([2875])
# rewards looks like  (3077,)
# logs prob looks like  torch.Size([3077])
# torch.from_numpy(rewards) looks like  torch.Size([3077])
# rewards looks like  (2799,)
# logs prob looks like  torch.Size([2799])
# torch.from_numpy(rewards) looks like  torch.Size([2799])
# rewards looks like  (2951,)
# logs prob looks like  torch.Size([2951])
# torch.from_numpy(rewards) looks like  torch.Size([2951])
# rewards looks like  (4578,)
# logs prob looks like  torch.Size([4578])
# torch.from_numpy(rewards) looks like  torch.Size([4578])
# rewards looks like  (3382,)
# logs prob looks like  torch.Size([3382])
# torch.from_numpy(rewards) looks like  torch.Size([3382])
# rewards looks like  (4515,)
# logs prob looks like  torch.Size([4515])
# torch.from_numpy(rewards) looks like  torch.Size([4515])
# rewards looks like  (3240,)
# logs prob looks like  torch.Size([3240])
# torch.from_numpy(rewards) looks like  torch.Size([3240])
# rewards looks like  (3975,)
# logs prob looks like  torch.Size([3975])
# torch.from_numpy(rewards) looks like  torch.Size([3975])
# rewards looks like  (3549,)
# logs prob looks like  torch.Size([3549])
# torch.from_numpy(rewards) looks like  torch.Size([3549])
# rewards looks like  (3770,)
# logs prob looks like  torch.Size([3770])
# torch.from_numpy(rewards) looks like  torch.Size([3770])
# rewards looks like  (3697,)
# logs prob looks like  torch.Size([3697])
# torch.from_numpy(rewards) looks like  torch.Size([3697])
# rewards looks like  (4100,)
# logs prob looks like  torch.Size([4100])
# torch.from_numpy(rewards) looks like  torch.Size([4100])
# rewards looks like  (3176,)
# logs prob looks like  torch.Size([3176])
# torch.from_numpy(rewards) looks like  torch.Size([3176])
# rewards looks like  (3471,)
# logs prob looks like  torch.Size([3471])
# torch.from_numpy(rewards) looks like  torch.Size([3471])
# rewards looks like  (3480,)
# logs prob looks like  torch.Size([3480])
# torch.from_numpy(rewards) looks like  torch.Size([3480])
# rewards looks like  (3276,)
# logs prob looks like  torch.Size([3276])
# torch.from_numpy(rewards) looks like  torch.Size([3276])
# rewards looks like  (5577,)
# logs prob looks like  torch.Size([5577])
# torch.from_numpy(rewards) looks like  torch.Size([5577])
# rewards looks like  (6800,)
# logs prob looks like  torch.Size([6800])
# torch.from_numpy(rewards) looks like  torch.Size([6800])
# rewards looks like  (4342,)
# logs prob looks like  torch.Size([4342])
# torch.from_numpy(rewards) looks like  torch.Size([4342])
# rewards looks like  (3356,)
# logs prob looks like  torch.Size([3356])
# torch.from_numpy(rewards) looks like  torch.Size([3356])
# rewards looks like  (5170,)
# logs prob looks like  torch.Size([5170])
# torch.from_numpy(rewards) looks like  torch.Size([5170])
# rewards looks like  (3369,)
# logs prob looks like  torch.Size([3369])
# torch.from_numpy(rewards) looks like  torch.Size([3369])
# rewards looks like  (3593,)
# logs prob looks like  torch.Size([3593])
# torch.from_numpy(rewards) looks like  torch.Size([3593])
# rewards looks like  (4518,)
# logs prob looks like  torch.Size([4518])
# torch.from_numpy(rewards) looks like  torch.Size([4518])
# rewards looks like  (4056,)
# logs prob looks like  torch.Size([4056])
# torch.from_numpy(rewards) looks like  torch.Size([4056])
# rewards looks like  (4204,)
# logs prob looks like  torch.Size([4204])
# torch.from_numpy(rewards) looks like  torch.Size([4204])
# rewards looks like  (3655,)
# logs prob looks like  torch.Size([3655])
# torch.from_numpy(rewards) looks like  torch.Size([3655])
# rewards looks like  (4040,)
# logs prob looks like  torch.Size([4040])
# torch.from_numpy(rewards) looks like  torch.Size([4040])
# rewards looks like  (3851,)
# logs prob looks like  torch.Size([3851])
# torch.from_numpy(rewards) looks like  torch.Size([3851])
# rewards looks like  (5993,)
# logs prob looks like  torch.Size([5993])
# torch.from_numpy(rewards) looks like  torch.Size([5993])
# rewards looks like  (4268,)
# logs prob looks like  torch.Size([4268])
# torch.from_numpy(rewards) looks like  torch.Size([4268])
# rewards looks like  (5167,)
# logs prob looks like  torch.Size([5167])
# torch.from_numpy(rewards) looks like  torch.Size([5167])
# rewards looks like  (4280,)
# logs prob looks like  torch.Size([4280])
# torch.from_numpy(rewards) looks like  torch.Size([4280])
# rewards looks like  (3438,)
# logs prob looks like  torch.Size([3438])
# torch.from_numpy(rewards) looks like  torch.Size([3438])
# rewards looks like  (3463,)
# logs prob looks like  torch.Size([3463])
# torch.from_numpy(rewards) looks like  torch.Size([3463])
# rewards looks like  (4304,)
# logs prob looks like  torch.Size([4304])
# torch.from_numpy(rewards) looks like  torch.Size([4304])
# rewards looks like  (5102,)
# logs prob looks like  torch.Size([5102])
# torch.from_numpy(rewards) looks like  torch.Size([5102])
# rewards looks like  (6081,)
# logs prob looks like  torch.Size([6081])
# torch.from_numpy(rewards) looks like  torch.Size([6081])
# rewards looks like  (4147,)
# logs prob looks like  torch.Size([4147])
# torch.from_numpy(rewards) looks like  torch.Size([4147])
# rewards looks like  (4245,)
# logs prob looks like  torch.Size([4245])
# torch.from_numpy(rewards) looks like  torch.Size([4245])
# rewards looks like  (3151,)
# logs prob looks like  torch.Size([3151])
# torch.from_numpy(rewards) looks like  torch.Size([3151])
# rewards looks like  (4219,)
# logs prob looks like  torch.Size([4219])
# torch.from_numpy(rewards) looks like  torch.Size([4219])
# rewards looks like  (3503,)
# logs prob looks like  torch.Size([3503])
# torch.from_numpy(rewards) looks like  torch.Size([3503])
# rewards looks like  (6664,)
# logs prob looks like  torch.Size([6664])
# torch.from_numpy(rewards) looks like  torch.Size([6664])
# rewards looks like  (4271,)
# logs prob looks like  torch.Size([4271])
# torch.from_numpy(rewards) looks like  torch.Size([4271])
# rewards looks like  (4649,)
# logs prob looks like  torch.Size([4649])
# torch.from_numpy(rewards) looks like  torch.Size([4649])
# rewards looks like  (4322,)
# logs prob looks like  torch.Size([4322])
# torch.from_numpy(rewards) looks like  torch.Size([4322])
# rewards looks like  (6037,)
# logs prob looks like  torch.Size([6037])
# torch.from_numpy(rewards) looks like  torch.Size([6037])
# rewards looks like  (4018,)
# logs prob looks like  torch.Size([4018])
# torch.from_numpy(rewards) looks like  torch.Size([4018])
# rewards looks like  (3889,)
# logs prob looks like  torch.Size([3889])
# torch.from_numpy(rewards) looks like  torch.Size([3889])
# rewards looks like  (5909,)
# logs prob looks like  torch.Size([5909])
# torch.from_numpy(rewards) looks like  torch.Size([5909])
# rewards looks like  (3799,)
# logs prob looks like  torch.Size([3799])
# torch.from_numpy(rewards) looks like  torch.Size([3799])
# rewards looks like  (5377,)
# logs prob looks like  torch.Size([5377])
# torch.from_numpy(rewards) looks like  torch.Size([5377])
# rewards looks like  (4411,)
# logs prob looks like  torch.Size([4411])
# torch.from_numpy(rewards) looks like  torch.Size([4411])
# rewards looks like  (6697,)
# logs prob looks like  torch.Size([6697])
# torch.from_numpy(rewards) looks like  torch.Size([6697])
# rewards looks like  (4508,)
# logs prob looks like  torch.Size([4508])
# torch.from_numpy(rewards) looks like  torch.Size([4508])
# rewards looks like  (6099,)
# logs prob looks like  torch.Size([6099])
# torch.from_numpy(rewards) looks like  torch.Size([6099])
# rewards looks like  (6425,)
# logs prob looks like  torch.Size([6425])
# torch.from_numpy(rewards) looks like  torch.Size([6425])
# rewards looks like  (4220,)
# logs prob looks like  torch.Size([4220])
# torch.from_numpy(rewards) looks like  torch.Size([4220])
# rewards looks like  (5549,)
# logs prob looks like  torch.Size([5549])
# torch.from_numpy(rewards) looks like  torch.Size([5549])
# rewards looks like  (7600,)
# logs prob looks like  torch.Size([7600])
# torch.from_numpy(rewards) looks like  torch.Size([7600])
# rewards looks like  (6664,)
# logs prob looks like  torch.Size([6664])
# torch.from_numpy(rewards) looks like  torch.Size([6664])
# rewards looks like  (7181,)
# logs prob looks like  torch.Size([7181])
# torch.from_numpy(rewards) looks like  torch.Size([7181])
# rewards looks like  (5115,)
# logs prob looks like  torch.Size([5115])
# torch.from_numpy(rewards) looks like  torch.Size([5115])
# rewards looks like  (6262,)
# logs prob looks like  torch.Size([6262])
# torch.from_numpy(rewards) looks like  torch.Size([6262])
# rewards looks like  (8185,)
# logs prob looks like  torch.Size([8185])
# torch.from_numpy(rewards) looks like  torch.Size([8185])
# rewards looks like  (4764,)
# logs prob looks like  torch.Size([4764])
# torch.from_numpy(rewards) looks like  torch.Size([4764])
# rewards looks like  (5056,)
# logs prob looks like  torch.Size([5056])
# torch.from_numpy(rewards) looks like  torch.Size([5056])
# rewards looks like  (8153,)
# logs prob looks like  torch.Size([8153])
# torch.from_numpy(rewards) looks like  torch.Size([8153])
# rewards looks like  (5541,)
# logs prob looks like  torch.Size([5541])
# torch.from_numpy(rewards) looks like  torch.Size([5541])
# rewards looks like  (7875,)
# logs prob looks like  torch.Size([7875])
# torch.from_numpy(rewards) looks like  torch.Size([7875])
# rewards looks like  (5455,)
# logs prob looks like  torch.Size([5455])
# torch.from_numpy(rewards) looks like  torch.Size([5455])
# rewards looks like  (7491,)
# logs prob looks like  torch.Size([7491])
# torch.from_numpy(rewards) looks like  torch.Size([7491])
# rewards looks like  (9006,)
# logs prob looks like  torch.Size([9006])
# torch.from_numpy(rewards) looks like  torch.Size([9006])
# rewards looks like  (4478,)
# logs prob looks like  torch.Size([4478])
# torch.from_numpy(rewards) looks like  torch.Size([4478])
# rewards looks like  (5969,)
# logs prob looks like  torch.Size([5969])
# torch.from_numpy(rewards) looks like  torch.Size([5969])
# rewards looks like  (5420,)
# logs prob looks like  torch.Size([5420])
# torch.from_numpy(rewards) looks like  torch.Size([5420])
# rewards looks like  (4744,)
# logs prob looks like  torch.Size([4744])
# torch.from_numpy(rewards) looks like  torch.Size([4744])
# rewards looks like  (6846,)
# logs prob looks like  torch.Size([6846])
# torch.from_numpy(rewards) looks like  torch.Size([6846])
# rewards looks like  (5025,)
# logs prob looks like  torch.Size([5025])
# torch.from_numpy(rewards) looks like  torch.Size([5025])
# rewards looks like  (5638,)
# logs prob looks like  torch.Size([5638])
# torch.from_numpy(rewards) looks like  torch.Size([5638])
# rewards looks like  (6796,)
# logs prob looks like  torch.Size([6796])
# torch.from_numpy(rewards) looks like  torch.Size([6796])
# rewards looks like  (5942,)
# logs prob looks like  torch.Size([5942])
# torch.from_numpy(rewards) looks like  torch.Size([5942])
# rewards looks like  (3811,)
# logs prob looks like  torch.Size([3811])
# torch.from_numpy(rewards) looks like  torch.Size([3811])
# rewards looks like  (3679,)
# logs prob looks like  torch.Size([3679])
# torch.from_numpy(rewards) looks like  torch.Size([3679])
# rewards looks like  (5525,)
# logs prob looks like  torch.Size([5525])
# torch.from_numpy(rewards) looks like  torch.Size([5525])
# rewards looks like  (5220,)
# logs prob looks like  torch.Size([5220])
# torch.from_numpy(rewards) looks like  torch.Size([5220])
# rewards looks like  (3956,)
# logs prob looks like  torch.Size([3956])
# torch.from_numpy(rewards) looks like  torch.Size([3956])
# rewards looks like  (4377,)
# logs prob looks like  torch.Size([4377])
# torch.from_numpy(rewards) looks like  torch.Size([4377])
# rewards looks like  (5351,)
# logs prob looks like  torch.Size([5351])
# torch.from_numpy(rewards) looks like  torch.Size([5351])
# rewards looks like  (5660,)
# logs prob looks like  torch.Size([5660])
# torch.from_numpy(rewards) looks like  torch.Size([5660])
# rewards looks like  (5447,)
# logs prob looks like  torch.Size([5447])
# torch.from_numpy(rewards) looks like  torch.Size([5447])
# rewards looks like  (6160,)
# logs prob looks like  torch.Size([6160])
# torch.from_numpy(rewards) looks like  torch.Size([6160])
# rewards looks like  (5034,)
# logs prob looks like  torch.Size([5034])
# torch.from_numpy(rewards) looks like  torch.Size([5034])
# rewards looks like  (7556,)
# logs prob looks like  torch.Size([7556])
# torch.from_numpy(rewards) looks like  torch.Size([7556])
# rewards looks like  (8955,)
# logs prob looks like  torch.Size([8955])
# torch.from_numpy(rewards) looks like  torch.Size([8955])
# rewards looks like  (6110,)
# logs prob looks like  torch.Size([6110])
# torch.from_numpy(rewards) looks like  torch.Size([6110])
# rewards looks like  (6737,)
# logs prob looks like  torch.Size([6737])
# torch.from_numpy(rewards) looks like  torch.Size([6737])
# rewards looks like  (5054,)
# logs prob looks like  torch.Size([5054])
# torch.from_numpy(rewards) looks like  torch.Size([5054])
# rewards looks like  (5711,)
# logs prob looks like  torch.Size([5711])
# torch.from_numpy(rewards) looks like  torch.Size([5711])
# rewards looks like  (6814,)
# logs prob looks like  torch.Size([6814])
# torch.from_numpy(rewards) looks like  torch.Size([6814])
# rewards looks like  (7831,)
# logs prob looks like  torch.Size([7831])
# torch.from_numpy(rewards) looks like  torch.Size([7831])
# rewards looks like  (10337,)
# logs prob looks like  torch.Size([10337])
# torch.from_numpy(rewards) looks like  torch.Size([10337])
# rewards looks like  (4822,)
# logs prob looks like  torch.Size([4822])
# torch.from_numpy(rewards) looks like  torch.Size([4822])
# rewards looks like  (5638,)
# logs prob looks like  torch.Size([5638])
# torch.from_numpy(rewards) looks like  torch.Size([5638])
# rewards looks like  (7111,)
# logs prob looks like  torch.Size([7111])
# torch.from_numpy(rewards) looks like  torch.Size([7111])
# rewards looks like  (7285,)
# logs prob looks like  torch.Size([7285])
# torch.from_numpy(rewards) looks like  torch.Size([7285])
# rewards looks like  (7505,)
# logs prob looks like  torch.Size([7505])
# torch.from_numpy(rewards) looks like  torch.Size([7505])
# rewards looks like  (6979,)
# logs prob looks like  torch.Size([6979])
# torch.from_numpy(rewards) looks like  torch.Size([6979])
# rewards looks like  (5853,)
# logs prob looks like  torch.Size([5853])
# torch.from_numpy(rewards) looks like  torch.Size([5853])
# rewards looks like  (7412,)
# logs prob looks like  torch.Size([7412])
# torch.from_numpy(rewards) looks like  torch.Size([7412])
# rewards looks like  (7748,)
# logs prob looks like  torch.Size([7748])
# torch.from_numpy(rewards) looks like  torch.Size([7748])
# rewards looks like  (8000,)
# logs prob looks like  torch.Size([8000])
# torch.from_numpy(rewards) looks like  torch.Size([8000])
# rewards looks like  (6469,)
# logs prob looks like  torch.Size([6469])
# torch.from_numpy(rewards) looks like  torch.Size([6469])
# rewards looks like  (11799,)
# logs prob looks like  torch.Size([11799])
# torch.from_numpy(rewards) looks like  torch.Size([11799])
# rewards looks like  (7655,)
# logs prob looks like  torch.Size([7655])
# torch.from_numpy(rewards) looks like  torch.Size([7655])
# rewards looks like  (8059,)
# logs prob looks like  torch.Size([8059])
# torch.from_numpy(rewards) looks like  torch.Size([8059])
# rewards looks like  (5399,)
# logs prob looks like  torch.Size([5399])
# torch.from_numpy(rewards) looks like  torch.Size([5399])
# rewards looks like  (5908,)
# logs prob looks like  torch.Size([5908])
# torch.from_numpy(rewards) looks like  torch.Size([5908])
# rewards looks like  (5842,)
# logs prob looks like  torch.Size([5842])
# torch.from_numpy(rewards) looks like  torch.Size([5842])
# rewards looks like  (10827,)
# logs prob looks like  torch.Size([10827])
# torch.from_numpy(rewards) looks like  torch.Size([10827])
# rewards looks like  (7552,)
# logs prob looks like  torch.Size([7552])
# torch.from_numpy(rewards) looks like  torch.Size([7552])
# rewards looks like  (7535,)
# logs prob looks like  torch.Size([7535])
# torch.from_numpy(rewards) looks like  torch.Size([7535])
# rewards looks like  (9241,)
# logs prob looks like  torch.Size([9241])
# torch.from_numpy(rewards) looks like  torch.Size([9241])
# rewards looks like  (6672,)
# logs prob looks like  torch.Size([6672])
# torch.from_numpy(rewards) looks like  torch.Size([6672])
# rewards looks like  (9566,)
# logs prob looks like  torch.Size([9566])
# torch.from_numpy(rewards) looks like  torch.Size([9566])
# rewards looks like  (8348,)
# logs prob looks like  torch.Size([8348])
# torch.from_numpy(rewards) looks like  torch.Size([8348])
# rewards looks like  (8527,)
# logs prob looks like  torch.Size([8527])
# torch.from_numpy(rewards) looks like  torch.Size([8527])
# rewards looks like  (6597,)
# logs prob looks like  torch.Size([6597])
# torch.from_numpy(rewards) looks like  torch.Size([6597])
# rewards looks like  (7628,)
# logs prob looks like  torch.Size([7628])
# torch.from_numpy(rewards) looks like  torch.Size([7628])
# rewards looks like  (9078,)
# logs prob looks like  torch.Size([9078])
# torch.from_numpy(rewards) looks like  torch.Size([9078])
# rewards looks like  (8590,)
# logs prob looks like  torch.Size([8590])
# torch.from_numpy(rewards) looks like  torch.Size([8590])
# rewards looks like  (12330,)
# logs prob looks like  torch.Size([12330])
# torch.from_numpy(rewards) looks like  torch.Size([12330])
# rewards looks like  (9221,)
# logs prob looks like  torch.Size([9221])
# torch.from_numpy(rewards) looks like  torch.Size([9221])
# rewards looks like  (8808,)
# logs prob looks like  torch.Size([8808])
# torch.from_numpy(rewards) looks like  torch.Size([8808])
# rewards looks like  (9981,)
# logs prob looks like  torch.Size([9981])
# torch.from_numpy(rewards) looks like  torch.Size([9981])
# rewards looks like  (10108,)
# logs prob looks like  torch.Size([10108])
# torch.from_numpy(rewards) looks like  torch.Size([10108])
# rewards looks like  (8634,)
# logs prob looks like  torch.Size([8634])
# torch.from_numpy(rewards) looks like  torch.Size([8634])
# rewards looks like  (8271,)
# logs prob looks like  torch.Size([8271])
# torch.from_numpy(rewards) looks like  torch.Size([8271])
# rewards looks like  (9125,)
# logs prob looks like  torch.Size([9125])
# torch.from_numpy(rewards) looks like  torch.Size([9125])
# rewards looks like  (9209,)
# logs prob looks like  torch.Size([9209])
# torch.from_numpy(rewards) looks like  torch.Size([9209])
# rewards looks like  (10847,)
# logs prob looks like  torch.Size([10847])
# torch.from_numpy(rewards) looks like  torch.Size([10847])
# rewards looks like  (14046,)
# logs prob looks like  torch.Size([14046])
# torch.from_numpy(rewards) looks like  torch.Size([14046])
# rewards looks like  (8149,)
# logs prob looks like  torch.Size([8149])
# torch.from_numpy(rewards) looks like  torch.Size([8149])
# rewards looks like  (9637,)
# logs prob looks like  torch.Size([9637])
# torch.from_numpy(rewards) looks like  torch.Size([9637])
# rewards looks like  (10425,)
# logs prob looks like  torch.Size([10425])
# torch.from_numpy(rewards) looks like  torch.Size([10425])
# rewards looks like  (11159,)
# logs prob looks like  torch.Size([11159])
# torch.from_numpy(rewards) looks like  torch.Size([11159])
# rewards looks like  (9600,)
# logs prob looks like  torch.Size([9600])
# torch.from_numpy(rewards) looks like  torch.Size([9600])
# rewards looks like  (12112,)
# logs prob looks like  torch.Size([12112])
# torch.from_numpy(rewards) looks like  torch.Size([12112])
# rewards looks like  (9368,)
# logs prob looks like  torch.Size([9368])
# torch.from_numpy(rewards) looks like  torch.Size([9368])
# rewards looks like  (13320,)
# logs prob looks like  torch.Size([13320])
# torch.from_numpy(rewards) looks like  torch.Size([13320])
# rewards looks like  (11398,)
# logs prob looks like  torch.Size([11398])
# torch.from_numpy(rewards) looks like  torch.Size([11398])
# rewards looks like  (10659,)
# logs prob looks like  torch.Size([10659])
# torch.from_numpy(rewards) looks like  torch.Size([10659])
# rewards looks like  (10962,)
# logs prob looks like  torch.Size([10962])
# torch.from_numpy(rewards) looks like  torch.Size([10962])
# rewards looks like  (11199,)
# logs prob looks like  torch.Size([11199])
# torch.from_numpy(rewards) looks like  torch.Size([11199])
# rewards looks like  (10933,)
# logs prob looks like  torch.Size([10933])
# torch.from_numpy(rewards) looks like  torch.Size([10933])
# rewards looks like  (10302,)
# logs prob looks like  torch.Size([10302])
# torch.from_numpy(rewards) looks like  torch.Size([10302])
# rewards looks like  (9461,)
# logs prob looks like  torch.Size([9461])
# torch.from_numpy(rewards) looks like  torch.Size([9461])
# rewards looks like  (14010,)
# logs prob looks like  torch.Size([14010])
# torch.from_numpy(rewards) looks like  torch.Size([14010])
# rewards looks like  (9521,)
# logs prob looks like  torch.Size([9521])
# torch.from_numpy(rewards) looks like  torch.Size([9521])
# rewards looks like  (10737,)
# logs prob looks like  torch.Size([10737])
# torch.from_numpy(rewards) looks like  torch.Size([10737])
# rewards looks like  (11263,)
# logs prob looks like  torch.Size([11263])
# torch.from_numpy(rewards) looks like  torch.Size([11263])
# rewards looks like  (13306,)
# logs prob looks like  torch.Size([13306])
# torch.from_numpy(rewards) looks like  torch.Size([13306])
# rewards looks like  (11871,)
# logs prob looks like  torch.Size([11871])
# torch.from_numpy(rewards) looks like  torch.Size([11871])
# rewards looks like  (11014,)
# logs prob looks like  torch.Size([11014])
# torch.from_numpy(rewards) looks like  torch.Size([11014])
# rewards looks like  (7512,)
# logs prob looks like  torch.Size([7512])
# torch.from_numpy(rewards) looks like  torch.Size([7512])
# rewards looks like  (12741,)
# logs prob looks like  torch.Size([12741])
# torch.from_numpy(rewards) looks like  torch.Size([12741])
# rewards looks like  (14131,)
# logs prob looks like  torch.Size([14131])
# torch.from_numpy(rewards) looks like  torch.Size([14131])
# rewards looks like  (9288,)
# logs prob looks like  torch.Size([9288])
# torch.from_numpy(rewards) looks like  torch.Size([9288])
# rewards looks like  (11185,)
# logs prob looks like  torch.Size([11185])
# torch.from_numpy(rewards) looks like  torch.Size([11185])
# rewards looks like  (11321,)
# logs prob looks like  torch.Size([11321])
# torch.from_numpy(rewards) looks like  torch.Size([11321])
# rewards looks like  (10191,)
# logs prob looks like  torch.Size([10191])
# torch.from_numpy(rewards) looks like  torch.Size([10191])
# rewards looks like  (12879,)
# logs prob looks like  torch.Size([12879])
# torch.from_numpy(rewards) looks like  torch.Size([12879])
# rewards looks like  (13181,)
# logs prob looks like  torch.Size([13181])
# torch.from_numpy(rewards) looks like  torch.Size([13181])
# rewards looks like  (13924,)
# logs prob looks like  torch.Size([13924])
# torch.from_numpy(rewards) looks like  torch.Size([13924])
# rewards looks like  (12231,)
# logs prob looks like  torch.Size([12231])
# torch.from_numpy(rewards) looks like  torch.Size([12231])
# rewards looks like  (12609,)
# logs prob looks like  torch.Size([12609])
# torch.from_numpy(rewards) looks like  torch.Size([12609])
# rewards looks like  (11101,)
# logs prob looks like  torch.Size([11101])
# torch.from_numpy(rewards) looks like  torch.Size([11101])
# rewards looks like  (14064,)
# logs prob looks like  torch.Size([14064])
# torch.from_numpy(rewards) looks like  torch.Size([14064])
# rewards looks like  (13799,)
# logs prob looks like  torch.Size([13799])
# torch.from_numpy(rewards) looks like  torch.Size([13799])
# rewards looks like  (13169,)
# logs prob looks like  torch.Size([13169])
# torch.from_numpy(rewards) looks like  torch.Size([13169])
# rewards looks like  (11772,)
# logs prob looks like  torch.Size([11772])
# torch.from_numpy(rewards) looks like  torch.Size([11772])
# rewards looks like  (13815,)
# logs prob looks like  torch.Size([13815])
# torch.from_numpy(rewards) looks like  torch.Size([13815])
# rewards looks like  (10362,)
# logs prob looks like  torch.Size([10362])
# torch.from_numpy(rewards) looks like  torch.Size([10362])
# rewards looks like  (13851,)
# logs prob looks like  torch.Size([13851])
# torch.from_numpy(rewards) looks like  torch.Size([13851])
# rewards looks like  (13588,)
# logs prob looks like  torch.Size([13588])
# torch.from_numpy(rewards) looks like  torch.Size([13588])
# rewards looks like  (13839,)
# logs prob looks like  torch.Size([13839])
# torch.from_numpy(rewards) looks like  torch.Size([13839])
# rewards looks like  (12421,)
# logs prob looks like  torch.Size([12421])
# torch.from_numpy(rewards) looks like  torch.Size([12421])
# rewards looks like  (16206,)
# logs prob looks like  torch.Size([16206])
# torch.from_numpy(rewards) looks like  torch.Size([16206])
# rewards looks like  (11974,)
# logs prob looks like  torch.Size([11974])
# torch.from_numpy(rewards) looks like  torch.Size([11974])
# rewards looks like  (15567,)
# logs prob looks like  torch.Size([15567])
# torch.from_numpy(rewards) looks like  torch.Size([15567])
# rewards looks like  (14186,)
# logs prob looks like  torch.Size([14186])
# torch.from_numpy(rewards) looks like  torch.Size([14186])
# rewards looks like  (15199,)
# logs prob looks like  torch.Size([15199])
# torch.from_numpy(rewards) looks like  torch.Size([15199])
# rewards looks like  (12392,)
# logs prob looks like  torch.Size([12392])
# torch.from_numpy(rewards) looks like  torch.Size([12392])
# rewards looks like  (14216,)
# logs prob looks like  torch.Size([14216])
# torch.from_numpy(rewards) looks like  torch.Size([14216])
# rewards looks like  (12710,)
# logs prob looks like  torch.Size([12710])
# torch.from_numpy(rewards) looks like  torch.Size([12710])
# rewards looks like  (14375,)
# logs prob looks like  torch.Size([14375])
# torch.from_numpy(rewards) looks like  torch.Size([14375])
# rewards looks like  (13510,)
# logs prob looks like  torch.Size([13510])
# torch.from_numpy(rewards) looks like  torch.Size([13510])
# rewards looks like  (15541,)
# logs prob looks like  torch.Size([15541])
# torch.from_numpy(rewards) looks like  torch.Size([15541])
# rewards looks like  (14703,)
# logs prob looks like  torch.Size([14703])
# torch.from_numpy(rewards) looks like  torch.Size([14703])
# rewards looks like  (13481,)
# logs prob looks like  torch.Size([13481])
# torch.from_numpy(rewards) looks like  torch.Size([13481])
# rewards looks like  (14149,)
# logs prob looks like  torch.Size([14149])
# torch.from_numpy(rewards) looks like  torch.Size([14149])
# rewards looks like  (12182,)
# logs prob looks like  torch.Size([12182])
# torch.from_numpy(rewards) looks like  torch.Size([12182])
# rewards looks like  (14140,)
# logs prob looks like  torch.Size([14140])
# torch.from_numpy(rewards) looks like  torch.Size([14140])
# rewards looks like  (10948,)
# logs prob looks like  torch.Size([10948])
# torch.from_numpy(rewards) looks like  torch.Size([10948])
# rewards looks like  (10980,)
# logs prob looks like  torch.Size([10980])
# torch.from_numpy(rewards) looks like  torch.Size([10980])
# rewards looks like  (12002,)
# logs prob looks like  torch.Size([12002])
# torch.from_numpy(rewards) looks like  torch.Size([12002])
# rewards looks like  (16005,)
# logs prob looks like  torch.Size([16005])
# torch.from_numpy(rewards) looks like  torch.Size([16005])
# rewards looks like  (12035,)
# logs prob looks like  torch.Size([12035])
# torch.from_numpy(rewards) looks like  torch.Size([12035])
# rewards looks like  (12845,)
# logs prob looks like  torch.Size([12845])
# torch.from_numpy(rewards) looks like  torch.Size([12845])
# rewards looks like  (14165,)
# logs prob looks like  torch.Size([14165])
# torch.from_numpy(rewards) looks like  torch.Size([14165])
# rewards looks like  (13281,)
# logs prob looks like  torch.Size([13281])
# torch.from_numpy(rewards) looks like  torch.Size([13281])
# rewards looks like  (13990,)
# logs prob looks like  torch.Size([13990])
# torch.from_numpy(rewards) looks like  torch.Size([13990])
# rewards looks like  (13791,)
# logs prob looks like  torch.Size([13791])
# torch.from_numpy(rewards) looks like  torch.Size([13791])
# rewards looks like  (12565,)
# logs prob looks like  torch.Size([12565])
# torch.from_numpy(rewards) looks like  torch.Size([12565])
# rewards looks like  (14452,)
# logs prob looks like  torch.Size([14452])
# torch.from_numpy(rewards) looks like  torch.Size([14452])
# rewards looks like  (16974,)
# logs prob looks like  torch.Size([16974])
# torch.from_numpy(rewards) looks like  torch.Size([16974])
# rewards looks like  (16651,)
# logs prob looks like  torch.Size([16651])
# torch.from_numpy(rewards) looks like  torch.Size([16651])
# rewards looks like  (13550,)
# logs prob looks like  torch.Size([13550])
# torch.from_numpy(rewards) looks like  torch.Size([13550])
# rewards looks like  (14479,)
# logs prob looks like  torch.Size([14479])
# torch.from_numpy(rewards) looks like  torch.Size([14479])
# rewards looks like  (14609,)
# logs prob looks like  torch.Size([14609])
# torch.from_numpy(rewards) looks like  torch.Size([14609])
# rewards looks like  (18079,)
# logs prob looks like  torch.Size([18079])
# torch.from_numpy(rewards) looks like  torch.Size([18079])
# rewards looks like  (15235,)
# logs prob looks like  torch.Size([15235])
# torch.from_numpy(rewards) looks like  torch.Size([15235])
# rewards looks like  (12378,)
# logs prob looks like  torch.Size([12378])
# torch.from_numpy(rewards) looks like  torch.Size([12378])
# rewards looks like  (13598,)
# logs prob looks like  torch.Size([13598])
# ...
# rewards looks like  (12903,)
# logs prob looks like  torch.Size([12903])
# torch.from_numpy(rewards) looks like  torch.Size([12903])
# rewards looks like  (13112,)
# logs prob looks like  torch.Size([13112])
# torch.from_numpy(rewards) looks like  torch.Size([13112])
# rewards looks like  (14411,)
# logs prob looks like  torch.Size([14411])
# torch.from_numpy(rewards) looks like  torch.Size([14411])
# rewards looks like  (13161,)
# logs prob looks like  torch.Size([13161])
# torch.from_numpy(rewards) looks like  torch.Size([13161])
# rewards looks like  (12020,)
# logs prob looks like  torch.Size([12020])
# torch.from_numpy(rewards) looks like  torch.Size([12020])
# rewards looks like  (13521,)
# logs prob looks like  torch.Size([13521])
# torch.from_numpy(rewards) looks like  torch.Size([13521])
# rewards looks like  (12984,)
# logs prob looks like  torch.Size([12984])
# torch.from_numpy(rewards) looks like  torch.Size([12984])
# rewards looks like  (13562,)
# logs prob looks like  torch.Size([13562])
# torch.from_numpy(rewards) looks like  torch.Size([13562])
# rewards looks like  (12987,)
# logs prob looks like  torch.Size([12987])
# torch.from_numpy(rewards) looks like  torch.Size([12987])
# rewards looks like  (12508,)
# logs prob looks like  torch.Size([12508])
# torch.from_numpy(rewards) looks like  torch.Size([12508])
# rewards looks like  (12663,)
# logs prob looks like  torch.Size([12663])
# torch.from_numpy(rewards) looks like  torch.Size([12663])
# rewards looks like  (12958,)
# logs prob looks like  torch.Size([12958])
# torch.from_numpy(rewards) looks like  torch.Size([12958])
# rewards looks like  (13098,)
# logs prob looks like  torch.Size([13098])
# torch.from_numpy(rewards) looks like  torch.Size([13098])
# rewards looks like  (13285,)
# logs prob looks like  torch.Size([13285])
# torch.from_numpy(rewards) looks like  torch.Size([13285])
# rewards looks like  (11829,)
# logs prob looks like  torch.Size([11829])
# torch.from_numpy(rewards) looks like  torch.Size([11829])
# rewards looks like  (13576,)
# logs prob looks like  torch.Size([13576])
# torch.from_numpy(rewards) looks like  torch.Size([13576])
# rewards looks like  (12385,)
# logs prob looks like  torch.Size([12385])
# torch.from_numpy(rewards) looks like  torch.Size([12385])
# rewards looks like  (13561,)
# logs prob looks like  torch.Size([13561])
# torch.from_numpy(rewards) looks like  torch.Size([13561])
# rewards looks like  (12843,)
# logs prob looks like  torch.Size([12843])
# torch.from_numpy(rewards) looks like  torch.Size([12843])
# rewards looks like  (12752,)
# logs prob looks like  torch.Size([12752])
# torch.from_numpy(rewards) looks like  torch.Size([12752])
# rewards looks like  (13321,)
# logs prob looks like  torch.Size([13321])
# torch.from_numpy(rewards) looks like  torch.Size([13321])
# rewards looks like  (13614,)
# logs prob looks like  torch.Size([13614])
# torch.from_numpy(rewards) looks like  torch.Size([13614])
# rewards looks like  (13306,)
# logs prob looks like  torch.Size([13306])
# torch.from_numpy(rewards) looks like  torch.Size([13306])
# rewards looks like  (13633,)
# logs prob looks like  torch.Size([13633])
# torch.from_numpy(rewards) looks like  torch.Size([13633])
# rewards looks like  (13258,)
# logs prob looks like  torch.Size([13258])
# torch.from_numpy(rewards) looks like  torch.Size([13258])
# rewards looks like  (13296,)
# logs prob looks like  torch.Size([13296])
# torch.from_numpy(rewards) looks like  torch.Size([13296])
# rewards looks like  (12729,)
# logs prob looks like  torch.Size([12729])
# torch.from_numpy(rewards) looks like  torch.Size([12729])
# rewards looks like  (14225,)
# logs prob looks like  torch.Size([14225])
# torch.from_numpy(rewards) looks like  torch.Size([14225])
# rewards looks like  (13264,)
# logs prob looks like  torch.Size([13264])
# torch.from_numpy(rewards) looks like  torch.Size([13264])
# rewards looks like  (12983,)
# logs prob looks like  torch.Size([12983])
# torch.from_numpy(rewards) looks like  torch.Size([12983])
# rewards looks like  (13512,)
# logs prob looks like  torch.Size([13512])
# torch.from_numpy(rewards) looks like  torch.Size([13512])
# rewards looks like  (12904,)
# logs prob looks like  torch.Size([12904])
# torch.from_numpy(rewards) looks like  torch.Size([12904])
# rewards looks like  (12303,)
# logs prob looks like  torch.Size([12303])
# torch.from_numpy(rewards) looks like  torch.Size([12303])
# rewards looks like  (13919,)
# logs prob looks like  torch.Size([13919])
# torch.from_numpy(rewards) looks like  torch.Size([13919])
# rewards looks like  (12541,)
# logs prob looks like  torch.Size([12541])
# torch.from_numpy(rewards) looks like  torch.Size([12541])
# rewards looks like  (13254,)
# logs prob looks like  torch.Size([13254])
# torch.from_numpy(rewards) looks like  torch.Size([13254])
# rewards looks like  (12722,)
# logs prob looks like  torch.Size([12722])
# torch.from_numpy(rewards) looks like  torch.Size([12722])
# rewards looks like  (12797,)
# logs prob looks like  torch.Size([12797])
# torch.from_numpy(rewards) looks like  torch.Size([12797])
# rewards looks like  (13392,)
# logs prob looks like  torch.Size([13392])
# torch.from_numpy(rewards) looks like  torch.Size([13392])
# rewards looks like  (12917,)
# logs prob looks like  torch.Size([12917])
# torch.from_numpy(rewards) looks like  torch.Size([12917])
# rewards looks like  (12971,)
# logs prob looks like  torch.Size([12971])
# torch.from_numpy(rewards) looks like  torch.Size([12971])
# rewards looks like  (11812,)
# logs prob looks like  torch.Size([11812])
# torch.from_numpy(rewards) looks like  torch.Size([11812])
# rewards looks like  (12932,)
# logs prob looks like  torch.Size([12932])
# torch.from_numpy(rewards) looks like  torch.Size([12932])
# rewards looks like  (13082,)
# logs prob looks like  torch.Size([13082])
# torch.from_numpy(rewards) looks like  torch.Size([13082])
# rewards looks like  (13376,)
# logs prob looks like  torch.Size([13376])
# torch.from_numpy(rewards) looks like  torch.Size([13376])
# rewards looks like  (12329,)
# logs prob looks like  torch.Size([12329])
# torch.from_numpy(rewards) looks like  torch.Size([12329])
# rewards looks like  (12786,)
# logs prob looks like  torch.Size([12786])
# torch.from_numpy(rewards) looks like  torch.Size([12786])
# rewards looks like  (13300,)
# logs prob looks like  torch.Size([13300])
# torch.from_numpy(rewards) looks like  torch.Size([13300])
# rewards looks like  (14243,)
# logs prob looks like  torch.Size([14243])
# torch.from_numpy(rewards) looks like  torch.Size([14243])
# rewards looks like  (13063,)
# logs prob looks like  torch.Size([13063])
# torch.from_numpy(rewards) looks like  torch.Size([13063])
# rewards looks like  (13078,)
# logs prob looks like  torch.Size([13078])
# torch.from_numpy(rewards) looks like  torch.Size([13078])
# rewards looks like  (13491,)
# logs prob looks like  torch.Size([13491])
# torch.from_numpy(rewards) looks like  torch.Size([13491])
# rewards looks like  (13443,)
# logs prob looks like  torch.Size([13443])
# torch.from_numpy(rewards) looks like  torch.Size([13443])
# rewards looks like  (13676,)
# logs prob looks like  torch.Size([13676])
# torch.from_numpy(rewards) looks like  torch.Size([13676])
# rewards looks like  (13153,)
# logs prob looks like  torch.Size([13153])
# torch.from_numpy(rewards) looks like  torch.Size([13153])
# rewards looks like  (13086,)
# logs prob looks like  torch.Size([13086])
# torch.from_numpy(rewards) looks like  torch.Size([13086])
# rewards looks like  (13573,)
# logs prob looks like  torch.Size([13573])
# torch.from_numpy(rewards) looks like  torch.Size([13573])
# rewards looks like  (12882,)
# logs prob looks like  torch.Size([12882])
# torch.from_numpy(rewards) looks like  torch.Size([12882])
# rewards looks like  (13171,)
# logs prob looks like  torch.Size([13171])
# torch.from_numpy(rewards) looks like  torch.Size([13171])
# rewards looks like  (13267,)
# logs prob looks like  torch.Size([13267])
# torch.from_numpy(rewards) looks like  torch.Size([13267])
# rewards looks like  (12716,)
# logs prob looks like  torch.Size([12716])
# torch.from_numpy(rewards) looks like  torch.Size([12716])
# rewards looks like  (13802,)
# logs prob looks like  torch.Size([13802])
# torch.from_numpy(rewards) looks like  torch.Size([13802])
# rewards looks like  (13700,)
# logs prob looks like  torch.Size([13700])
# torch.from_numpy(rewards) looks like  torch.Size([13700])
# rewards looks like  (13299,)
# logs prob looks like  torch.Size([13299])
# torch.from_numpy(rewards) looks like  torch.Size([13299])
# rewards looks like  (13596,)
# logs prob looks like  torch.Size([13596])
# torch.from_numpy(rewards) looks like  torch.Size([13596])
# rewards looks like  (12764,)
# logs prob looks like  torch.Size([12764])
# torch.from_numpy(rewards) looks like  torch.Size([12764])
# rewards looks like  (12896,)
# logs prob looks like  torch.Size([12896])
# torch.from_numpy(rewards) looks like  torch.Size([12896])
# rewards looks like  (12619,)
# logs prob looks like  torch.Size([12619])
# torch.from_numpy(rewards) looks like  torch.Size([12619])
# rewards looks like  (11918,)
# logs prob looks like  torch.Size([11918])
# torch.from_numpy(rewards) looks like  torch.Size([11918])
# rewards looks like  (12241,)
# logs prob looks like  torch.Size([12241])
# torch.from_numpy(rewards) looks like  torch.Size([12241])
# rewards looks like  (12920,)
# logs prob looks like  torch.Size([12920])
# torch.from_numpy(rewards) looks like  torch.Size([12920])
# rewards looks like  (12432,)
# logs prob looks like  torch.Size([12432])
# torch.from_numpy(rewards) looks like  torch.Size([12432])
# rewards looks like  (13212,)
# logs prob looks like  torch.Size([13212])
# torch.from_numpy(rewards) looks like  torch.Size([13212])
# rewards looks like  (12110,)
# logs prob looks like  torch.Size([12110])
# torch.from_numpy(rewards) looks like  torch.Size([12110])
# rewards looks like  (12226,)
# logs prob looks like  torch.Size([12226])
# torch.from_numpy(rewards) looks like  torch.Size([12226])
# rewards looks like  (12665,)
# logs prob looks like  torch.Size([12665])
# torch.from_numpy(rewards) looks like  torch.Size([12665])
# rewards looks like  (12768,)
# logs prob looks like  torch.Size([12768])
# torch.from_numpy(rewards) looks like  torch.Size([12768])
# rewards looks like  (13077,)
# logs prob looks like  torch.Size([13077])
# torch.from_numpy(rewards) looks like  torch.Size([13077])
# rewards looks like  (12090,)
# logs prob looks like  torch.Size([12090])
# torch.from_numpy(rewards) looks like  torch.Size([12090])
# rewards looks like  (12099,)
# logs prob looks like  torch.Size([12099])
# torch.from_numpy(rewards) looks like  torch.Size([12099])
# rewards looks like  (11538,)
# logs prob looks like  torch.Size([11538])
# torch.from_numpy(rewards) looks like  torch.Size([11538])
# rewards looks like  (12928,)
# logs prob looks like  torch.Size([12928])
# torch.from_numpy(rewards) looks like  torch.Size([12928])
# rewards looks like  (11429,)
# logs prob looks like  torch.Size([11429])
# torch.from_numpy(rewards) looks like  torch.Size([11429])
# rewards looks like  (12691,)
# logs prob looks like  torch.Size([12691])
# torch.from_numpy(rewards) looks like  torch.Size([12691])
# rewards looks like  (12847,)
# logs prob looks like  torch.Size([12847])
# torch.from_numpy(rewards) looks like  torch.Size([12847])
# rewards looks like  (12391,)
# logs prob looks like  torch.Size([12391])
# torch.from_numpy(rewards) looks like  torch.Size([12391])
# rewards looks like  (12936,)
# logs prob looks like  torch.Size([12936])
# torch.from_numpy(rewards) looks like  torch.Size([12936])
# rewards looks like  (12091,)
# logs prob looks like  torch.Size([12091])
# torch.from_numpy(rewards) looks like  torch.Size([12091])
# rewards looks like  (11705,)
# logs prob looks like  torch.Size([11705])
# torch.from_numpy(rewards) looks like  torch.Size([11705])
# rewards looks like  (12015,)
# logs prob looks like  torch.Size([12015])
# torch.from_numpy(rewards) looks like  torch.Size([12015])
# rewards looks like  (12207,)
# logs prob looks like  torch.Size([12207])
# torch.from_numpy(rewards) looks like  torch.Size([12207])
# rewards looks like  (11085,)
# logs prob looks like  torch.Size([11085])
# torch.from_numpy(rewards) looks like  torch.Size([11085])
# rewards looks like  (11142,)
# logs prob looks like  torch.Size([11142])
# torch.from_numpy(rewards) looks like  torch.Size([11142])
# rewards looks like  (11825,)
# logs prob looks like  torch.Size([11825])
# torch.from_numpy(rewards) looks like  torch.Size([11825])
# rewards looks like  (12383,)
# logs prob looks like  torch.Size([12383])
# torch.from_numpy(rewards) looks like  torch.Size([12383])
# rewards looks like  (11553,)
# logs prob looks like  torch.Size([11553])
# torch.from_numpy(rewards) looks like  torch.Size([11553])
# rewards looks like  (12186,)
# logs prob looks like  torch.Size([12186])
# torch.from_numpy(rewards) looks like  torch.Size([12186])
# rewards looks like  (12643,)
# logs prob looks like  torch.Size([12643])
# torch.from_numpy(rewards) looks like  torch.Size([12643])
# rewards looks like  (12023,)
# logs prob looks like  torch.Size([12023])
# torch.from_numpy(rewards) looks like  torch.Size([12023])
# rewards looks like  (12919,)
# logs prob looks like  torch.Size([12919])
# torch.from_numpy(rewards) looks like  torch.Size([12919])
# rewards looks like  (12450,)
# logs prob looks like  torch.Size([12450])
# torch.from_numpy(rewards) looks like  torch.Size([12450])
# rewards looks like  (12840,)
# logs prob looks like  torch.Size([12840])
# torch.from_numpy(rewards) looks like  torch.Size([12840])
# rewards looks like  (13154,)
# logs prob looks like  torch.Size([13154])
# torch.from_numpy(rewards) looks like  torch.Size([13154])
# rewards looks like  (12391,)
# logs prob looks like  torch.Size([12391])
# torch.from_numpy(rewards) looks like  torch.Size([12391])
# rewards looks like  (12730,)
# logs prob looks like  torch.Size([12730])
# torch.from_numpy(rewards) looks like  torch.Size([12730])
# rewards looks like  (12574,)
# logs prob looks like  torch.Size([12574])
# torch.from_numpy(rewards) looks like  torch.Size([12574])
# rewards looks like  (13128,)
# logs prob looks like  torch.Size([13128])
# torch.from_numpy(rewards) looks like  torch.Size([13128])
# rewards looks like  (13447,)
# logs prob looks like  torch.Size([13447])
# torch.from_numpy(rewards) looks like  torch.Size([13447])
# rewards looks like  (12473,)
# logs prob looks like  torch.Size([12473])
# torch.from_numpy(rewards) looks like  torch.Size([12473])
# rewards looks like  (12896,)
# logs prob looks like  torch.Size([12896])
# torch.from_numpy(rewards) looks like  torch.Size([12896])
# rewards looks like  (12966,)
# logs prob looks like  torch.Size([12966])
# torch.from_numpy(rewards) looks like  torch.Size([12966])
# rewards looks like  (13136,)
# logs prob looks like  torch.Size([13136])
# torch.from_numpy(rewards) looks like  torch.Size([13136])
# rewards looks like  (13405,)
# logs prob looks like  torch.Size([13405])
# torch.from_numpy(rewards) looks like  torch.Size([13405])
# rewards looks like  (13704,)
# logs prob looks like  torch.Size([13704])
# torch.from_numpy(rewards) looks like  torch.Size([13704])
# rewards looks like  (13524,)
# logs prob looks like  torch.Size([13524])
# torch.from_numpy(rewards) looks like  torch.Size([13524])
# rewards looks like  (12624,)
# logs prob looks like  torch.Size([12624])
# torch.from_numpy(rewards) looks like  torch.Size([12624])
# rewards looks like  (12213,)
# logs prob looks like  torch.Size([12213])
# torch.from_numpy(rewards) looks like  torch.Size([12213])
# rewards looks like  (12921,)
# logs prob looks like  torch.Size([12921])
# torch.from_numpy(rewards) looks like  torch.Size([12921])
# rewards looks like  (12489,)
# logs prob looks like  torch.Size([12489])
# torch.from_numpy(rewards) looks like  torch.Size([12489])
# rewards looks like  (12069,)
# logs prob looks like  torch.Size([12069])
# torch.from_numpy(rewards) looks like  torch.Size([12069])
# rewards looks like  (13014,)
# logs prob looks like  torch.Size([13014])
# torch.from_numpy(rewards) looks like  torch.Size([13014])
# rewards looks like  (13019,)
# logs prob looks like  torch.Size([13019])
# torch.from_numpy(rewards) looks like  torch.Size([13019])
# rewards looks like  (12632,)
# logs prob looks like  torch.Size([12632])
# torch.from_numpy(rewards) looks like  torch.Size([12632])
# rewards looks like  (12749,)
# logs prob looks like  torch.Size([12749])
# torch.from_numpy(rewards) looks like  torch.Size([12749])

# %% [markdown]
# ### Training Result
# During the training process, we recorded `avg_total_reward`, which represents the average total reward of episodes before updating the policy network.
#
# Theoretically, if the agent becomes better, the `avg_total_reward` will increase.
# The visualization of the training process is shown below:

# %%
plt.plot(avg_total_rewards)
plt.title("Total Rewards")
plt.show()

# %% [markdown]
# In addition, `avg_final_reward` represents average final rewards of episodes. To be specific, final rewards is the last reward received in one episode, indicating whether the craft lands successfully or not.

# %%
plt.plot(avg_final_rewards)
plt.title("Final Rewards")
plt.show()

# %% [markdown]
# ## Testing
# The testing result will be the average reward of 5 testing

# %%
fix(env, seed)
agent.network.eval()  # set the network into evaluation mode
NUM_OF_TEST = 5 # Do not revise this !!!
test_total_reward = []
action_list = []
for i in range(NUM_OF_TEST):
  actions = []
  state = env.reset()

  img = plt.imshow(env.render(mode='rgb_array'))

  total_reward = 0

  done = False
  while not done:
      action, _ = agent.sample(state)
      actions.append(action)
      state, reward, done, _ = env.step(action)

      total_reward += reward

      img.set_data(env.render(mode='rgb_array'))
      display.display(plt.gcf())
      display.clear_output(wait=True)

  print(total_reward)
  test_total_reward.append(total_reward)

  action_list.append(actions) # save the result of testing
# Out:
# -18.986137752132592

# %%
print(np.mean(test_total_reward))
# Out:
# -135.44134600245144

# %% [markdown]
# Action list

# %%
print("Action list looks like ", action_list)
print("Action list's shape looks like ", np.shape(action_list))
# Out:
# Action list looks like  [[0, 2, 0, 0, 2, 3, 3, 2, 2, 0, 0, 3, 2, 2, 2, 1, 1, 2, 3, 2, 2, 3, 2, 0, 1, 0, 0, 1, 2, 0, 1, 2, 0, 0, 3, 2, 0, 1, 1, 0, 2, 1, 3, 2, 1, 0, 3, 1, 2, 2, 1, 2, 0, 0, 1, 3, 0, 1, 0, 0, 0, 1, 3, 0, 3, 3, 0, 1, 3, 3, 0, 3, 0, 3, 1, 2, 1, 0, 0, 0, 1, 3, 0, 0, 3, 3, 2, 1, 1, 0, 1, 2, 0, 1, 1, 2, 2, 1, 3, 0, 0, 0, 1, 0, 2, 1, 0, 1, 1, 0, 0, 3, 1, 1], [0, 3, 2, 0, 2, 1, 2, 0, 0, 3, 0, 1, 3, 1, 0, 2, 2, 0, 0, 1, 1, 1, 0, 3, 2, 0, 1, 0, 2, 0, 3, 1, 2, 0, 3, 0, 1, 0, 3, 3, 2, 0, 0, 1, 1, 2, 0, 3, 3, 1, 3, 2, 0, 0, 3, 3, 2, 3, 1, 3, 0, 0, 3, 2, 1, 0, 0, 1, 2, 0, 2, 2, 1, 0, 2, 1, 1, 1, 0, 1, 2, 0, 2, 1, 0], [0, 0, 3, 1, 2, 1, 0, 2, 0, 0, 0, 3, 2, 1, 2, 3, 3, 2, 2, 1, 0, 2, 0, 1, 3, 2, 0, 0, 2, 0, 2, 0, 1, 1, 2, 0, 2, 2, 2, 2, 1, 1, 2, 1, 0, 2, 3, 0, 1, 2, 0, 0, 1, 1, 2, 3, 0, 1, 0, 2, 0, 0, 3, 1, 0, 0, 1, 0, 3, 0, 0, 2, 0, 2, 0, 3, 3], [1, 1, 3, 3, 0, 3, 0, 3, 2, 3, 1, 0, 2, 0, 2, 1, 1, 3, 2, 1, 1, 3, 1, 3, 1, 1, 0, 3, 0, 2, 1, 0, 2, 3, 3, 3, 3, 1, 2, 1, 3, 3, 0, 2, 3, 0, 1, 3, 1, 3, 1, 3, 3, 0, 0, 3, 1, 0, 1, 1, 2, 2, 2, 1, 0, 3, 3, 3, 2, 0, 0, 2, 1, 1, 2, 0, 2, 2, 3, 2, 2, 0, 1, 2, 2, 0, 2, 0, 2], [2, 0, 0, 2, 1, 0, 0, 1, 0, 1, 1, 2, 0, 2, 3, 2, 1, 1, 1, 2, 3, 2, 0, 3, 1, 0, 1, 2, 2, 3, 1, 0, 2, 1, 2, 2, 2, 2, 0, 1, 1, 1, 2, 3, 3, 2, 3, 1, 0, 0, 3, 1, 3, 2, 0, 3, 2, 3, 2, 2, 3, 1, 3, 2, 1, 3, 2, 3, 3, 3, 3, 2, 2, 1, 2, 1, 3, 3, 3, 2, 1, 3, 0, 1, 2, 1]]
# Action list's shape looks like  (5,)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:2007: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape

# %% [markdown]
# Analysis of actions taken by agent

# %%
distribution = {}
for actions in action_list:
  for action in actions:
    if action not in distribution.keys():
      distribution[action] = 1
    else:
      distribution[action] += 1
print(distribution)
# Out:
# {0: 128, 2: 115, 3: 95, 1: 113}

# %% [markdown]
# Saving the result of Model Testing

# %%
PATH = "Action_List.npy" # Can be modified into the name or path you want
np.save(PATH ,np.array(action_list))
# Out:
# <ipython-input-33-0cd63aefc5d4>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.save(PATH ,np.array(action_list))

# %% [markdown]
# ### This is the file you need to submit !!!
# Download the testing result to your device

# %%
from google.colab import files
files.download(PATH)

# %% [markdown]
# # Server
# The code below simulate the environment on the judge server. Can be used for testing.

# %%
action_list = np.load(PATH,allow_pickle=True) # The action list you upload
seed = 2023 # Do not revise this
fix(env, seed)

agent.network.eval()  # set network to evaluation mode

test_total_reward = []
if len(action_list) != 5:
  print("Wrong format of file !!!")
  exit(0)
for actions in action_list:
  state = env.reset()
  img = plt.imshow(env.render(mode='rgb_array'))

  total_reward = 0

  done = False

  for action in actions:

      state, reward, done, _ = env.step(action)
      total_reward += reward
      if done:
        break

  print(f"Your reward is : %.2f"%total_reward)
  test_total_reward.append(total_reward)
# Out:
# Your reward is : -299.41
# Your reward is : -117.25
# Your reward is : -105.11
# Your reward is : -136.45
# Your reward is : -18.99

# %% [markdown]
# # Your score

# %%
print(f"Your final reward is : %.2f"%np.mean(test_total_reward))
# Out:
# Your final reward is : -135.44

# %% [markdown]
# ## Reference
#
# Below are some useful tips for you to get high score.
#
# - [DRL Lecture 1: Policy Gradient (Review)](https://youtu.be/z95ZYgPgXOY)
# - [ML Lecture 23-3: Reinforcement Learning (including Q-learning) start at 30:00](https://youtu.be/2-JNBzCq77c?t=1800)
# - [Lecture 7: Policy Gradient, David Silver](http://www0.cs.ucl.ac.uk/staff/d.silver/web/Teaching_files/pg.pdf)
